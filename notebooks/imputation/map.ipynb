# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'C:\Users\Shibbs\Desktop\Praxis\CAPP\cwd\datasets\mice_0.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# event_time            0
# event_type            0
# product_id            0
# category_id           0
# price                 0
# user_id               0
# user_session        165
# brand                 0
# category_code         0
# category_code_L1      0
# category_code_L2      0
# dtype: int64

# %% [markdown]
# ### Mapping Dictionary

# %%
L1_category_map_values = ['Motion sensors', 'accessories', 'apparel', 'appliances', 'auto',
        'communication devices', 'computer', 'computers',
        'computers.gaming', 'construction', 'cosmetics', 'country_yard',
        'electrical', 'electronic', 'electronics', 'furniture', 'jewelry',
        'jwellery', 'kids', 'medicine', 'personalhygiene', 'products',
        'sport', 'stationary', 'stationery', 'tools', 'tv']

# %%
L1_category_map_keys = [*range(0,len(L1_category_map_values))]

# %%
L1_category_map_dict = dict(zip(L1_category_map_keys, L1_category_map_values))

# %%
L2_category_map_values = ['Mosquito_Repeller', 'accesories', 'accessories', 'appliances',
        'audio', 'auto', 'bag', 'bandages', 'banknote_counter', 'bath',
        'bathroom', 'battery', 'bedroom', 'bicycle', 'binding',
        'binding_machines', 'boots', 'briefcase', 'brush', 'calculator',
        'camera', 'car', 'cartrige', 'chemical', 'clocks',
        'communications', 'compnents', 'component', 'components',
        'cosmetic', 'cosmetics', 'counterfeit_detection', 'cultivator',
        'deodorent', 'desktop', 'drawers', 'ebooks',
        'electrical_components', 'electronics', 'environment', 'fax',
        'first_aidkit', 'flat_panel', 'gaming', 'glove', 'home', 'iron',
        'jeans', 'keychain', 'kitchen', 'lawn_mower', 'living_room',
        'measurement', 'multimeter', 'network', 'networking', 'notebook',
        'office', 'paper', 'paper_shredder', 'pen', 'pencil',
        'peripherals', 'personal', 'personel', 'pesticide', 'phone',
        'phone_covers', 'powerbank', 'punch', 'radio', 'ring', 'screen',
        'sewing_machine', 'skates', 'smoke', 'souvenir', 'stapler',
        'steam_cleaner', 'stencil', 't_shirt', 'tablet', 'telephone',
        'toolkit', 'tools', 'toys', 'video', 'videorecorder', 'watering',
        'weather_station']

# %%
L2_category_map_keys = [*range(0,len(L2_category_map_values))]

# %%
L2_category_map_dict = dict(zip(L2_category_map_keys, L2_category_map_values))

# %%
brand_map_values = ['a-data', 'accesstyle', 'accord', 'acct', 'acecamp', 'acer',
        'achi', 'acmepower', 'acorp', 'acqua', 'activecam', 'activision',
        'acv', 'adaptec', 'adata', 'aerocool', 'agestar', 'aimoto',
        'airmax', 'airwheel', 'ajax', 'akel', 'akenori', 'alan', 'alas',
        'alcatel', 'alfa', 'alienware', 'alligator', 'allocacoc',
        'alpenkok', 'alphachem', 'alpine', 'amazfit', 'amd', 'amega',
        'amtech', 'and', 'andis', 'anker', 'anl', 'anymode', 'anytek',
        'aoc', 'aopen', 'aorus', 'aosenma', 'apacer', 'apc', 'apexto',
        'apple', 'aqc', 'araree', 'arctic', 'arian', 'ark', 'artway',
        'asahi', 'asrock', 'astralux', 'asus', 'asustor', 'asx', 'aten',
        'atis', 'atrix', 'auchan', 'audio-technica', 'aukey', 'aura',
        'autobot', 'autoprofi', 'avaya', 'avengers', 'avermedia',
        'avinity', 'avis', 'avision', 'axon', 'b.well', 'bakon', 'baku',
        'ballet', 'ballistix', 'ballu', 'baofeng', 'barva', 'baseus',
        'batterika', 'battleground', 'bayerhoff', 'bb', 'bbk', 'beats',
        'beecaro', 'behpex', 'beko', 'belkin', 'bellavita', 'belsis',
        'benq', 'bento', 'berkut', 'beurer', 'beward', 'bion', 'biostal',
        'bkt', 'blast', 'blaupunkt', 'boneco', 'borofone', 'bort', 'bosch',
        'boyscout', 'bq', 'bracket', 'bradex', 'brand-rex', 'braun',
        'bresser', 'brita', 'brother', 'btcdigger', 'buro', 'buttkicker',
        'bwt', 'c-media', 'cablexpert', 'cactus', 'cadena', 'camelion',
        'cameronsino', 'camping', 'campingaz', 'candy', 'canon', 'canton',
        'canyon', 'capdase', 'carmega', 'carrefour', 'carver', 'casio',
        'cassida', 'casual', 'catalyst', 'caterpillar', 'cbr', 'celebrat',
        'cello', 'celly', 'cem', 'cenmax', 'centek', 'cet', 'chairman',
        'chieftec', 'cigii', 'cipherlab', 'cisco', 'citizen', 'cleanfix',
        'cnd', 'cobra', 'codyson', 'college', 'comfort', 'content',
        'continent', 'coocazoo', 'cooler', 'coolpad', 'coroplast',
        'corsair', 'coteetci', 'cougar', 'cozistyle', 'craftmann',
        'creative', 'crown', 'crownman', 'crucial', 'crumpler', 'csb',
        'cw', 'cyberflux', 'cyberpower', 'cybertek', 'd-color', 'd-link',
        'da', 'dahua', 'darina', 'datalogic', 'dato', 'davinci', 'dayrex',
        'dccraft', 'deepcool', 'defender', 'deli', 'dell', 'delonghi',
        'delta', 'delux', 'dendy', 'denon', 'deppa', 'dewalt', 'dexx',
        'df', 'dialog', 'digis', 'digma', 'digoldy', 'diolex', 'dji',
        'docash', 'dockcase', 'dolmer', 'dors', 'dremel', 'dsk',
        'duracell', 'dyp', 'e-blue', 'e.o.s', 'easyprint', 'eaton',
        'ecola', 'econ', 'edge', 'edifier', 'edimax', 'edisson', 'egreat',
        'ekf', 'elago', 'elari', 'electrolux', 'electronicsdeluxe',
        'elekta', 'element', 'elp', 'eltax', 'emtec', 'endever',
        'energizer', 'energy', 'enermax', 'engenius', 'engy', 'epson',
        'erisson', 'escene', 'espada', 'euroflex', 'eurolux', 'eva',
        'evga', 'exegate', 'explay', 'exployd', 'ezviz', 'falcon',
        'fantasy', 'fanvil', 'fastcharger', 'faura', 'favourite',
        'felisatti', 'fellowes', 'fengshou', 'fibaro', 'fiesta', 'fiio',
        'filtero', 'first', 'fiskars', 'fit', 'flexis', 'fli', 'fluke',
        'fly', 'formula', 'forward', 'foxconn', 'foxline', 'foxweld',
        'fractal', 'fsp', 'fubag', 'fujifilm', 'fujitsu',
        'fujitsu-siemens', 'fukai', 'funtastique', 'g-case', 'galanz',
        'galaxy', 'gamemax', 'gamerstorm', 'gamevice', 'ganzo', 'gaoke',
        'gardena', 'gauss', 'gazer', 'gbc', 'gefest', 'geha', 'geil',
        'gembird', 'genius', 'gerber', 'gfgril', 'giaretti', 'gigabyte',
        'gigalink', 'gigaset', 'gillette', 'ginzzu', 'glacialtech',
        'gladwork', 'gmini', 'goip', 'goldenberg', 'goodram', 'google',
        'goot', 'gorenje', 'gp', 'grandstream', 'greenconnect',
        'greenworks', 'greys', 'grinda', 'h-tek', 'haff', 'haier', 'hama',
        'hammer', 'hammerflex', 'hanlong', 'hanp', 'hansa', 'hanskonner',
        'harizma', 'harper', 'hartens', 'heddy', 'helfer', 'hercules',
        'hgst', 'hi-black', 'hideit', 'hikoki', 'hikvision', 'hiper',
        'hipro', 'hitachi', 'hiwatch', 'hoco', 'holder', 'homestar',
        'hometree', 'honeywell', 'honor', 'hoover', 'horizont',
        'hotpoint-ariston', 'hp', 'hpe', 'hsm', 'htc', 'hualei', 'huawei',
        'huayu', 'huion', 'human', 'husqvarna', 'huter', 'hynix',
        'hyperdrive', 'hyperjuice', 'hyperline', 'hyperx', 'hyundai',
        'i-blason', 'iboto', 'ibox', 'icasemore', 'iclebo', 'iconbit',
        'iconik', 'id-cooling', 'iek', 'ifans', 'iiyama', 'imex', 'imou',
        'in', 'incar', 'indesit', 'infinity', 'infocus', 'infortrend',
        'inkax', 'inktec', 'inoi', 'inspector', 'intego', 'integral',
        'intel', 'interos', 'interpower', 'intex', 'intro', 'ion',
        'ionich', 'iottie', 'ip-com', 'ipearl', 'ipega', 'ippon',
        'iqfuture', 'irbis', 'irit', 'isa', 'ismartdigi', 'istorage',
        'itk', 'itskins', 'ivon', 'jabra', 'jaguar', 'jakemy', 'janome',
        'jbl', 'jekod', 'jet', 'jet.a', 'jett', 'jison', 'jisoncase',
        'jonnesway', 'joyroom', 'jpn', 'justice', 'jvc', 'jxd', 'kada',
        'kaisi', 'karcher', 'katun', 'kbt', 'keenetic', 'kelli', 'kemper',
        'kenweiipc', 'kenwood', 'kes', 'kester', 'keter', 'kingmax',
        'kingston', 'kitfort', 'kivi', 'klevv', 'knipex', 'kobra', 'kodak',
        'komfort', 'konoos', 'koogeek', 'koowheel', 'koss', 'kraft',
        'kraftmark', 'kraftool', 'kramer', 'krez', 'kromax', 'krups',
        'ks-is', 'kutis', 'kw-trio', 'kyocera', 'lacie', 'lamirel',
        'lanmaster', 'lara', 'laut', 'lazso', 'ldnio', 'leatherman',
        'leeco', 'leef', 'leitz', 'lenovo', 'leomax', 'leonord',
        'levenhuk', 'lex', 'lexand', 'lexar', 'lexmark', 'lg', 'lifx',
        'lighthouse', 'linkworld', 'lite-on', 'logitech', 'lomond', 'lp',
        'lsi', 'lucia', 'lugaabrasiv', 'lukey', 'lumiix', 'luminarte',
        'lunatik', 'luphie', 'lux', 'luxele', 'luxell', 'lyambda',
        'macuus', 'magistr', 'magner', 'magnit', 'maguse', 'makel',
        'makita', 'mallony', 'maono', 'marshall', 'marvo', 'mastech',
        'master', 'masters', 'maunfeld', 'max', 'maxcut', 'maxtor',
        'maxwell', 'mcdodo', 'mechanic', 'meephone', 'megajet', 'megaopt',
        'meizu', 'melitta', 'mellanox', 'memumi', 'mercury', 'mercusys',
        'merrylock', 'metabo', 'metalloni', 'microlab', 'microlife',
        'micromax', 'microsoft', 'microtek', 'midea', 'midland',
        'mikrotik', 'military', 'millennium', 'mindeo', 'mio', 'mirex',
        'mitsubishi', 'mobest', 'mobilepc', 'mobility', 'mobparts',
        'molex', 'momax', 'moniron', 'monsterpad', 'moodo', 'mophie',
        'morel', 'moshi', 'most', 'motorola', 'moulinex', 'moxom', 'msi',
        'multitronics', 'munkees', 'mustek', 'muvit', 'mxq', 'myantenna',
        'mykronoz', 'myriwell', 'mystery', 'nakamichi', 'nakatomi',
        'nanoleaf', 'navan', 'navigator', 'navitel', 'navitoch', 'ncl',
        'ncp', 'nec', 'necchi', 'neoclima', 'neoline', 'neomax',
        'neon-night', 'netgear', 'netis', 'netproduct', 'nika', 'nikon',
        'nillkin', 'ninebot', 'ningbo', 'nintendo', 'nobby', 'noirot',
        'nokia', 'noname', 'noreve', 'nubia', 'nv-print', 'nzxt', 'oasis',
        'oce', 'ogden', 'oki', 'oklick', 'oldi', 'olsa', 'olto',
        'oltramax', 'olympus', 'ombra', 'oneplus', 'onkron', 'oppo',
        'optim', 'optima', 'optimus', 'optoma', 'oral-b', 'orico',
        'orient', 'osnovo', 'osram', 'oukitel', 'outdoor', 'oxion', 'oxo',
        'ozaki', 'ozone', 'p.i.t', 'p.i.t.', 'palit', 'palmexx',
        'panasonic', 'panduit', 'pantum', 'paprcuts', 'park', 'parkmaster',
        'parlux', 'patriot', 'pccooler', 'peakmeter', 'pengfa', 'perfeo',
        'pero', 'pgytech', 'phantom', 'philips', 'photofast', 'picard',
        'pilot', 'pilotage', 'pioneer', 'piquadro', 'pitaka', 'pitatel',
        'plantronics', 'playme', 'plextor', 'plustek', 'pmma', 'pny',
        'pocketbook', 'pockets', 'polaris', 'polaroid', 'portcase',
        'positive', 'powercase', 'powercolor', 'powercom', 'powercool',
        'powerman', 'powerware', 'pozitiv', 'prestigio', 'primeline',
        'printpro', 'pro', 'procase', 'proconnect', 'proda', 'prology',
        'promo', 'proskit', 'pullman', 'qcyber', 'qnap', 'quantoom',
        'qumo', 'raco', 'raidmax', 'rapoo', 'razer', 'realme', 'recardo',
        'red', 'redline', 'redmi', 'redmond', 'redragon', 'rekam',
        'relife', 'remaks', 'remax', 'remington', 'resmed', 'revolter',
        'rexant', 'rexel', 'ricoh', 'ritmix', 'riva', 'rivacase',
        'robiton', 'roccat', 'rokform', 'rolsen', 'romix', 'romoss',
        'rondell', 'rotring', 'rovermate', 'rowenta', 'royal', 'rubetek',
        'rus', 'rusflux', 'saeco', 'sago', 'saitek', 'samsonite',
        'samsung', 'sandisk', 'sanitas', 'sanyo', 'sapphire', 'saturn',
        'sbs', 'scarlett', 'sceye', 'scher-khan', 'scoole', 'scovo',
        'screenmedia', 'sea', 'seagate', 'sega', 'selenga', 'sencor',
        'sennheiser', 'sharkoon', 'sharp', 'sheriff', 'shivaki', 'sho-me',
        'siemens', 'silex', 'silverstone', 'silwerhof', 'sinbo', 'singer',
        'sirius', 'sjcam', 'skiff', 'sky', 'skymoto', 'skynet', 'skyworth',
        'sleepphones', 'smartbuy', 'smarterra', 'smarttools', 'smile',
        'smtt', 'snr', 'solarbox', 'solder', 'solins', 'sony', 'soundmax',
        'soundstream', 'sparco', 'sparks', 'sparky', 'speedlink', 'spigen',
        'spl', 'sprintus', 'st-lab', 'stanley', 'starline', 'starwind',
        'stayer', 'steel', 'steelseries', 'steinel', 'stlab', 'street',
        'strike', 'sumdex', 'sunon', 'sunpro', 'sunshine', 'superfine',
        'supermicro', 'supra', 'svc', 'sven', 'svetocopy', 'swat',
        'switcheasy', 'syma', 'synology', 'tactix', 'tantos', 'taonga',
        'targus', 'tcl', 'tdm', 'teco', 'tedbaker', 'tefal', 'telecom',
        'telefunken', 'tenda', 'termit', 'tesla', 'tesler', 'texet',
        'thermacell', 'thermaltake', 'thermos', 'thetford', 'thinmax',
        'thomas', 'thomson', 'thorvik', 'thronmax', 'thrustmaster',
        'thule', 'tiger', 'timberk', 'titan', 'tm', 'tomahawk',
        'tomoegawa', 'top', 'topon', 'toshiba', 'totolink', 'tp-link',
        'tranking', 'transcend', 'trassir', 'trendnet', 'trendvision',
        'tripplite', 'trust', 'tt', 'tuarex', 'turbokids', 'tv-com',
        'twinkly', 'tws', 'twt', 'ubiquiti', 'ubtech', 'ufc', 'ugreen',
        'ultraflash', 'ultramounts', 'uni-t', 'unibob', 'unify', 'uninet',
        'uniq', 'unit', 'universal', 'unv', 'upvel', 'uragan', 'ural',
        'urban', 'urbano', 'uyue', 'valera', 'vari', 'varta', 'vcom',
        'vehicle', 'ventura', 'verbatim', 'vertex', 'verus', 'vetus',
        'victorinox', 'videovox', 'videx', 'viewsonic', 'vigilant',
        'vigor', 'vikend', 'vitek', 'vitesse', 'vitherum', 'vlk', 'vr',
        'vs', 'vstarcam', 'w.e.p', 'w.e.p.', 'wacom', 'wahl', 'webber',
        'wester', 'western', 'wharfedale', 'whirlpool', 'wietus', 'wiiix',
        'willmark', 'winard', 'wispen', 'wits', 'wiwu', 'wize', 'wk',
        'wolta', 'wuw', 'wwq', 'x-try', 'xdm', 'xerox', 'xiaomi', 'xp-pen',
        'xtrememac', 'yaesu', 'yamaha', 'yaxun', 'yealink', 'yeastar',
        'yihua', 'yison', 'yixing', 'yoobao', 'yuasa', 'zalman', 'zebra',
        'zencha', 'zenet', 'zens', 'zeon', 'zepter', 'zetton', 'zhengte',
        'zhongdi', 'zikko', 'zimber', 'zis', 'zmi', 'zoweetek', 'zowie',
        'zte', 'zyxel']

# %%
brand_map_keys = [*range(0,len(brand_map_values))]

# %%
brand_map_dict = dict(zip(brand_map_keys, brand_map_values))

# %%
category_code_values = ['Motion sensors',
 'accessories.auto.components',
 'accessories.bag',
 'accessories.boots',
 'accessories.briefcase',
 'accessories.compnents.toilet',
 'accessories.electrical_components',
 'accessories.electronics',
 'accessories.home.lights',
 'accessories.keychain',
 'accessories.mobile.cryptocurrencies',
 'accessories.phone.display',
 'accessories.phone_covers',
 'accessories.toolkit',
 'apparel.drawers',
 'apparel.glove',
 'apparel.jeans',
 'apparel.t_shirt',
 'appliances.car.components',
 'appliances.environment.air_freshener',
 'appliances.environment.air_heater',
 'appliances.environment.air_purifier',
 'appliances.environment.fan',
 'appliances.environment.vacuum',
 'appliances.iron',
 'appliances.kitchen',
 'appliances.kitchen.blender',
 'appliances.kitchen.coffee_grinder',
 'appliances.kitchen.coffee_machine',
 'appliances.kitchen.cookware',
 'appliances.kitchen.fryer',
 'appliances.kitchen.grill',
 'appliances.kitchen.juicer',
 'appliances.kitchen.kettle',
 'appliances.kitchen.meat_grinder',
 'appliances.kitchen.microwave',
 'appliances.kitchen.mixer',
 'appliances.kitchen.refrigerator',
 'appliances.kitchen.refrigerators',
 'appliances.kitchen.steam_cooker',
 'appliances.kitchen.toster',
 'appliances.kitchen.washer',
 'appliances.measurement',
 'appliances.personal.bpm_monitor',
 'appliances.personal.hair_cutter',
 'appliances.personal.hair_dryer',
 'appliances.personal.massager',
 'appliances.personal.scales',
 'appliances.personal.smartbulb',
 'appliances.personal.smartlight',
 'appliances.personel.smartlight',
 'appliances.sewing_machine',
 'appliances.steam_cleaner',
 'appliances.toolkit',
 'auto.accesories.battery',
 'auto.accessories.alarm',
 'auto.accessories.battery',
 'auto.accessories.cleaner',
 'auto.accessories.compressor',
 'auto.accessories.gps',
 'auto.accessories.immobilizer',
 'auto.accessories.light',
 'auto.accessories.parktronic',
 'auto.accessories.player',
 'auto.accessories.radar',
 'auto.accessories.videoregister',
 'auto.accessories.winch',
 'auto.accessories.window',
 'communication_devices',
 'computer.components.hdd',
 'computer.components.sound_card',
 'computer.electronics.ai',
 'computer.electronics.hub',
 'computer.networking.products',
 'computer.peripherals.powersupply',
 'computer.peripherals.printer',
 'computer.peripherals.scanner',
 'computer.peripherals.virtual_reality',
 'computer.peripherals.webcam',
 'computer.peripherals.wifi',
 'computers.gaming',
 'computers.components.cdrw',
 'computers.components.cooler',
 'computers.components.cpu',
 'computers.components.hardware_security_module',
 'computers.components.hdd',
 'computers.components.ic_chips',
 'computers.components.motherboard',
 'computers.components.network_adapter',
 'computers.components.power_supply',
 'computers.components.ram',
 'computers.components.sdd',
 'computers.components.sound_card',
 'computers.components.ssd',
 'computers.components.tv_tuner',
 'computers.components.videocards',
 'computers.desktop',
 'computers.ebooks',
 'computers.gaming',
 'computers.network.router',
 'computers.notebook',
 'computers.peripherals.cable',
 'computers.peripherals.camera',
 'computers.peripherals.joystick',
 'computers.peripherals.keyboard',
 'computers.peripherals.monitor',
 'computers.peripherals.mouse',
 'computers.peripherals.nas',
 'computers.peripherals.plug',
 'computers.peripherals.printer',
 'computers.peripherals.scanner',
 'computers.peripherals.usbcable',
 'computers.peripherals.vr',
 'computers.peripherals.wifi',
 'construction.tools.abrasive',
 'construction.tools.drill',
 'construction.tools.generator',
 'construction.tools.heater',
 'construction.tools.light',
 'construction.tools.mold',
 'construction.tools.painting',
 'construction.tools.pliers',
 'construction.tools.pump',
 'construction.tools.saw',
 'construction.tools.screw',
 'construction.tools.smelting',
 'construction.tools.soldering',
 'construction.tools.welding',
 'construction.tools.wrench',
 'cosmetics',
 'country_yard.cultivator',
 'country_yard.lawn_mower',
 'country_yard.watering',
 'country_yard.weather_station',
 'electrical.tools.power_distribution',
 'electrical.tools.radio',
 'electrical.tools.switchgear',
 'electronic.smoke.vapour',
 'electronics.Mosquito_Repeller',
 'electronics.appliances',
 'electronics.audio',
 'electronics.audio.acoustic',
 'electronics.audio.av',
 'electronics.audio.dictaphone',
 'electronics.audio.headphone',
 'electronics.audio.microphone',
 'electronics.audio.music_tools.piano',
 'electronics.banknote_counter',
 'electronics.calculator',
 'electronics.camera.battery',
 'electronics.camera.photo',
 'electronics.camera.stand',
 'electronics.camera.video',
 'electronics.clocks',
 'electronics.communications',
 'electronics.components.metal_packages',
 'electronics.components.radio',
 'electronics.counterfeit_detection',
 'electronics.fax',
 'electronics.flat_panel',
 'electronics.multimeter',
 'electronics.pesticide',
 'electronics.powerbank',
 'electronics.radio',
 'electronics.screen',
 'electronics.tablet',
 'electronics.telephone',
 'electronics.telephone.accesories',
 'electronics.telephone.cover',
 'electronics.video.projector',
 'electronics.video.tv',
 'electronics.video.tv_mount',
 'electronics.video.tv_remote',
 'electronics.videorecorder',
 'furniture.bathroom.bath',
 'furniture.bedroom.bed',
 'furniture.bedroom.blanket',
 'furniture.kitchen.chair',
 'furniture.living_room.chair',
 'furniture.living_room.shelving',
 'furniture.office.chair',
 'jewelry.ring',
 'jewelry.souvenir',
 'jwellery',
 'kids.skates',
 'kids.toys',
 'medicine.bandages',
 'medicine.first_aidkit',
 'medicine.tools.tonometer',
 'personalhygiene.bath.body_wash',
 'personalhygiene.bath.scrub',
 'personalhygiene.brush.toothbrush',
 'personalhygiene.brush.toothpaste',
 'personalhygiene.deodorent',
 'products.chemical',
 'products.cosmetic',
 'products.cosmetics',
 'sport.bicycle',
 'stationary.binding_machines',
 'stationary.paper_shredder',
 'stationary.pencil',
 'stationery.battery',
 'stationery.binding',
 'stationery.cartrige',
 'stationery.paper',
 'stationery.pen',
 'stationery.punch',
 'stationery.stapler',
 'tools.stencil',
 'tv.component',
 'tv.components.stand']

# %%
category_code_keys = [*range(0,len(category_code_values))]

# %%
category_code_map_dict = dict(zip(category_code_keys, category_code_values))

# %% [markdown]
# ### Replacing dataframe with mapping dictionary.

# %%
df = df.replace({"category_code":category_code_map_dict, "brand":brand_map_dict, "category_code_L1":L1_category_map_dict, "category_code_L2":L2_category_map_dict})

# %%
df.to_csv(r'C:\Users\Omkar\Desktop\final.csv')

# %%
df.category_code.nunique()
# Out:
# 210

# %%
df.category_code_L1.nunique()
# Out:
# 27

# %%
df.category_code_L2.nunique()
# Out:
# 92

# %%
df.brand.nunique()
# Out:
# 999

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#                      event_time event_type  product_id   category_id  price  \
# 0       2020-11-20 15:19:47 UTC       view     1642613  2.144416e+18  25.56
# 1       2020-10-18 18:29:34 UTC       view     1642613  2.144416e+18  25.56
# 2       2020-11-20 19:18:47 UTC       view     1642613  2.144416e+18  25.56
# 3       2020-12-20 01:25:28 UTC       view     1642613  2.144416e+18  25.56
# 4       2021-02-24 15:59:50 UTC       view     1642613  2.144416e+18  25.56
# ...                         ...        ...         ...           ...    ...
# 885119  2020-12-02 14:01:32 UTC       view     1529443  2.144420e+18  13.24
# 885120  2021-01-06 13:14:08 UTC       view     1529453  2.144420e+18  66.19
# 885121  2020-10-08 12:10:00 UTC       view      864264  2.144420e+18  20.63
# 885122  2020-10-08 12:10:02 UTC       view      864264  2.144420e+18  20.63
# 885123  2020-12-31 06:47:03 UTC       view      703481  2.144420e+18  29.86
#
# ...

# %%
df.to_csv(r'C:\Users\Shibbs\Desktop\Praxis\CAPP\cwd\datasets\mappedmice_0.csv')

# %%
df.category_code.astype

# %%
df.info()

# %%
df.isnull().sum()
# Out:
# event_time            0
# event_type            0
# product_id            0
# category_id           0
# price                 0
# user_id               0
# user_session        165
# brand                 0
# category_code         0
# category_code_L1      0
# category_code_L2      0
# dtype: int64
